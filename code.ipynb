# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn import preprocessing
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

# %%
# pip install -U kaleido

# %%
def normalizar(df):
  df_norm = df.apply(lambda a: a/a.sum(), axis = 1)
  return df_norm
def scaler(df):
  scaler = preprocessing.StandardScaler().fit(df)
  data_scaled = scaler.transform(df)
  return data_scaled

def get_confidence_ellipse(data, n_std=1.96):
  mean = np.mean(data, axis=0)
  mean = np.mean(data, axis=0)
  cov = np.cov(data, rowvar=False)
  # Use Singular Value Decomposition (SVD) para garantir valores válidos
  U, S, Vt = np.linalg.svd(cov)
  eigvals = S
  eigvecs = U
  width, height = 2 * n_std * np.sqrt(eigvals)
  angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
  return mean, width, height, angle

def get_axis_limits_with_margin(data, margin=0.3):
    data_min, data_max = np.min(data), np.max(data)
    data_range = data_max - data_min
    return data_min - margin * data_range, data_max + margin * data_range

def plot2D(data, colors, dm, blank_tag):
    fig = go.Figure()
    for i, label in enumerate(labels.Method.unique()):
        print(label)
        print(colors[i])
        df = data[data.Method == label]
        fig.add_trace(go.Scatter(
        x = df.PC1.to_list(),
        y = df.PC2.to_list(),
        mode='markers+text',
        text = df.Sample.to_list(),
        textposition="top center",
        marker=dict(color=colors[i], size=8),
        name=f'{label}'
    ))
        try:
            mean, width, height, angle = get_confidence_ellipse(df[["PC1","PC2"]])
            ellipse_x = mean[0] + width * np.cos(np.linspace(0, 2 * np.pi, 100)) * np.cos(np.radians(angle)) - height * np.sin(np.linspace(0, 2 * np.pi, 100)) * np.sin(np.radians(angle))
            ellipse_y = mean[1] + width * np.cos(np.linspace(0, 2 * np.pi, 100)) * np.sin(np.radians(angle)) + height * np.sin(np.linspace(0, 2 * np.pi, 100)) * np.cos(np.radians(angle))

            fig.add_trace(go.Scatter(
            x=ellipse_x,
            y=ellipse_y,
            mode='lines',
            line=dict(color=colors[i]),
            showlegend=False

        ))
        except:
            pass
    fig.update_layout(
        title = f"PCA {table}",
        xaxis=dict(
            title = f"PC2 {round(dm.explained_variance_ratio_[0]*100)}%",
            showgrid=True,
            showline=True,
            linewidth=1,
            linecolor='black'
        ),
        yaxis=dict(
            title = f"PC2 {round(dm.explained_variance_ratio_[1]*100)}%",
            showgrid=True,
            showline=True,
            linewidth=1,
            linecolor='black'
        ),
        plot_bgcolor='white',
        paper_bgcolor='white',
        height=600,
        width=800
    )
    fig.show()
    fig.write_image(f"Figures/PCA-2D-{blank_tag}.png", format = "png")

def plot3D(data, colors, dm, blank_tag):

    x_limits = get_axis_limits_with_margin(data.PC1)
    y_limits = get_axis_limits_with_margin(data.PC2)
    z_limits = get_axis_limits_with_margin(data.PC3)

    fig = go.Figure()
    for i, label in enumerate(labels.Method.unique()):
        df = data[data.Method == label]

        fig.add_trace(go.Scatter3d(
            x=df.PC1.to_list(),
            y=df.PC2.to_list(),
            z=df.PC3.to_list(),
            mode='markers+text',
            text=df.Sample.to_list(),
            textposition="top center",
            marker=dict(color=colors[i], size=8),
            name=f'{label}'
        ))

    fig.update_layout(
        title=f"PCA {table}",
        scene=dict(
            xaxis=dict(
                title=f"PC1 {round(dm.explained_variance_ratio_[0]*100)}%",
                showgrid=True,
                showline=True,
                linewidth=1,
                linecolor='black',
                range = x_limits
            ),
            yaxis=dict(
                title=f"PC2 {round(dm.explained_variance_ratio_[1]*100)}%",
                showgrid=True,
                showline=True,
                linewidth=1,
                linecolor='black',
                range = y_limits
            ),
            zaxis=dict(
                title=f"PC3 {round(dm.explained_variance_ratio_[2]*100)}%",
                showgrid=True,
                showline=True,
                linewidth=1,
                linecolor='black',
                range = z_limits
            )
        ),
        plot_bgcolor='white',
        paper_bgcolor='white',
        height=600,
        width=800
    )

    fig.show()
    # fig.write_image(f"Figures/PCA-3D-{blank_tag}.png", format = "png")

# %%
table = "Quant_table_mzmine"
df = pd.read_excel(f"data/{table}.xlsx")
df.fillna(0.0, inplace = True)
labels = df[["Step","Method","Sample"]]
colors = ["black","blue","green","cyan","pink"]

# %%
df_with_blank = df.copy()
data_with_blank = df_with_blank.iloc[:,3:]
data_with_blank = scaler(data_with_blank)

# %%
df_no_blank = df.loc[df.Method != "Blank"].copy()
data_no_blank = df_no_blank.iloc[:,3:]
data_no_blank = scaler(data_no_blank)

# %%
pca_with_blank = PCA(n_components = 3)
pca_with_blank.fit(data_with_blank)
pca_with_blank_ = pca_with_blank.transform(data_with_blank)
pca_with_blank_df = pd.DataFrame({
    'PC1':pca_with_blank_[:,0],
    'PC2':pca_with_blank_[:,1],
    'PC3':pca_with_blank_[:,2],
    "Step": labels.Step.to_list(),
    "Method": labels.Method.to_list(),
    "Sample": labels.Sample.to_list()
})

pca_no_blank = PCA(n_components = 3)
pca_no_blank.fit(data_no_blank)
pca_no_blank_ = pca_no_blank.transform(data_no_blank)
pca_no_blank_df = pd.DataFrame({
    'PC1':pca_no_blank_[:,0],
    'PC2':pca_no_blank_[:,1],
    'PC3':pca_no_blank_[:,2],
    "Step":   labels[labels.Method != "Blank"].Step.to_list(),
    "Method": labels[labels.Method != "Blank"].Method.to_list(),
    "Sample": labels[labels.Method != "Blank"].Sample.to_list()
})

# %%
plot2D(pca_no_blank_df, colors, pca_no_blank, "noblank");
# Out:
# Blank
# black
# TRADITIONAL METHOD
# blue
# ALTERNATIVE METHOD
# green
# TRADITIONAL MODIFIED
# cyan
# ALTERNATIVE MODIFIED
# pink
# /home/tiago/anaconda3/envs/procera/lib/python3.12/site-packages/numpy/lib/function_base.py:520: RuntimeWarning:
#
# Mean of empty slice.
#
# /home/tiago/anaconda3/envs/procera/lib/python3.12/site-packages/numpy/core/_methods.py:121: RuntimeWarning:
#
# invalid value encountered in divide
#
# /tmp/ipykernel_962733/2026748030.py:12: RuntimeWarning:
#
# Degrees of freedom <= 0 for slice
#
# /home/tiago/anaconda3/envs/procera/lib/python3.12/site-packages/numpy/lib/function_base.py:2748: RuntimeWarning:
#
# divide by zero encountered in divide
#
# /home/tiago/anaconda3/envs/procera/lib/python3.12/site-packages/numpy/lib/function_base.py:2748: RuntimeWarning:
#
# invalid value encountered in multiply
#
# /tmp/ipykernel_962733/2026748030.py:43: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_962733/2026748030.py:44: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_962733/2026748030.py:43: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_962733/2026748030.py:44: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_962733/2026748030.py:43: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_962733/2026748030.py:44: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_962733/2026748030.py:43: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_962733/2026748030.py:44: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# <div>                            <div id="8cf7a33f-0341-40a9-b194-18e17c4536a6" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8cf7a33f-0341-40a9-b194-18e17c4536a6")) {                    Plotly.newPlot(                        "8cf7a33f-0341-40a9-b194-18e17c4536a6",                        [{"marker":{"color":"black","size":8},"mode":"markers+text","name":"Blank","text":[],"textposition":"top center","x":[],"y":[],"type":"scatter"},{"marker":{"color":"blue","size":8},"mode":"markers+text","name":"TRADITIONAL METHOD","text":["FM_HEX","FM_HEX","FM_HEX","E_MeOH","E_MeOH","E_MeOH","FMAcOEt","FMAcOEt","FMAcOEt"],"textposition":"top center","x":[-2.716515391323981,-2.719291507103697,-2.7167677654857734,-10.660640830235486,-10.493268945106832,-10.576954887671162,-3.990056088858251,-3.989749814609779,-3.9919651983404076],"y":[-4.03590365479025,-4.036076673084413,-4.035919383726083,21.965940864169635,21.399781653445554,21.682861258807616,-10.172867518102425,-10.171031152342865,-10.184314198003701],"type":"scatter"},{"line":{"color":"blue"},"mode":"lines","showlegend":false,"x":[-19.375615674131783,-19.630244761435584,-19.82903007372689,-19.971171172713138,-20.056095706356526,-20.08346171353366,-20.053159000992295,-19.96530958706068,-19.82026721032282,-19.61861590523803,-19.361167650440322,-19.048959099187,-18.68324740512191,-18.265505160161375,-17.79741446488634,-17.280860155316976,-16.7179222133433,-16.110867391372196,-15.462140084915525,-14.774352489872134,-14.050274084136912,-13.292820475890789,-12.505041663475648,-11.69010975412746,-10.851306191020027,-9.992008540051499,-9.11567688957857,-8.225839917861897,-7.326080684324175,-6.420022201834442,-5.511312848113986,-4.603611675006939,-3.70057367476993,-2.8058350627082715,-1.9229986354203326,-1.05561926360717,-0.207189577862946,0.6188740949158364,1.4192454878729048,2.19070178789493,2.930136612742407,3.634572519354601,4.301172992961835,4.92725386872939,5.510294139941882,6.047946109207575,6.538044841807147,6.978616883121712,7.367888205038059,7.704291349333707,7.986471739277981,8.213293134034384,8.383842203901423,8.497432207968984,8.553605759381565,8.552136667073738,8.493030846561712,8.376526296123663,8.20309213846465,7.973426731725059,7.688454857438858,7.34932399676475,6.957399709984543,6.514260137873867,6.02168964708626,5.481671645138446,4.896380593928263,4.268173253944125,3.5995791944222733,2.8932906076642935,2.1521514685288974,1.3791460827489588,0.5773870701855719,-0.24989716859351851,-1.0993754519435779,-1.9676272306356006,-2.851156361200858,-3.746405183666666,-4.649768846997461,-5.557609824557564,-6.4662725611471625,-7.372098192632877,-8.271439278902204,-9.160674490817577,-10.036223192030642,-10.894559856941086,-11.732228266743865,-12.545855426402568,-13.332165146509874,-14.087991235346045,-14.810290248015427,-15.496153741324942,-16.142819985058278,-16.747685082488754,-17.308313455352362,-17.82244765106189,-18.288017432671676,-18.703148114991116,-19.066168113280305,-19.375615674131783],"y":[59.86391847413849,59.68148320231504,59.26875911863968,58.62740811732896,57.760012692504326,56.67006553939974,55.36195549051069,53.84094984331476,52.11317315072376,50.18558255967071,48.065939797134725,45.7627799164058,43.28537692943772,40.64370646367505,37.848405593722305,34.91073000959873,31.842508694047325,28.65609629139621,25.36432335976646,21.980444706943004,18.518086017941876,14.991188989185757,11.413955190213125,7.800788878970057,4.166239000947385,0.524940605712199,-3.108444083271481,-6.719284708241604,-10.293041688425111,-13.81532476579806,-17.271950949575743,-20.649001626110753,-23.93287860423767,-27.110358870389522,-30.16864783300632,-33.09543084183971,-35.878922774702865,-38.50791549199836,-40.971822967940184,-43.260723916743544,-45.36540174214092,-47. ...

# %%
plot2D(pca_with_blank_df, colors, pca_with_blank, "blank");
# Out:
# Blank
# black
# TRADITIONAL METHOD
# blue
# ALTERNATIVE METHOD
# green
# TRADITIONAL MODIFIED
# cyan
# ALTERNATIVE MODIFIED
# pink
# /tmp/ipykernel_962733/2026748030.py:43: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_962733/2026748030.py:44: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_962733/2026748030.py:43: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_962733/2026748030.py:44: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_962733/2026748030.py:43: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_962733/2026748030.py:44: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_962733/2026748030.py:43: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_962733/2026748030.py:44: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_962733/2026748030.py:43: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_962733/2026748030.py:44: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# <div>                            <div id="d9452c5c-1038-41cd-b6ad-d2e72cee7456" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9452c5c-1038-41cd-b6ad-d2e72cee7456")) {                    Plotly.newPlot(                        "d9452c5c-1038-41cd-b6ad-d2e72cee7456",                        [{"marker":{"color":"black","size":8},"mode":"markers+text","name":"Blank","text":["BCO_HEPT","BCO_EtOAc","BCO_EtOH","BCO_MEOH","BCO_HEX"],"textposition":"top center","x":[-2.9311360349885973,-2.9311360349885973,-2.9311360349885973,-2.9818865453148153,-3.0104892262314142],"y":[-3.8978801095991757,-3.8978801095991757,-3.8978801095991757,-3.7153938387658503,-4.086593724830583],"type":"scatter"},{"line":{"color":"black"},"mode":"lines","showlegend":false,"x":[-2.912469524455661,-2.9213208333291103,-2.9303164408928133,-2.939420125010055,-2.9485952283579837,-2.957804806033714,-2.9670117743184066,-2.9761790600003226,-2.9852697496555565,-2.99424723828537,-3.0030753767115987,-3.0117186171366366,-3.0201421562818704,-3.0283120755281976,-3.0361954774943354,-3.0437606185029633,-3.05097703640131,-3.057815673221487,-3.0642489921866756,-3.0702510885920016,-3.0757977941136434,-3.0808667741261413,-3.0854376176360483,-3.089491919469802,-3.0930133543848584,-3.0959877428056823,-3.0984031079198955,-3.1002497239046716,-3.10152015508919,-3.102209285895463,-3.1023143414369576,-3.1018348986920867,-3.1007728882075676,-3.0991325863247914,-3.096920597960506,-3.094145830011146,-3.0908194554879085,-3.086954868526973,-3.082567630456051,-3.077675407134405,-3.0722978978186717,-3.066456755840907,-3.0601755014182603,-3.0534794269453633,-3.0463954951507795,-3.0389522305276166,-3.0311796044754575,-3.023108914616115,-3.0147726587691532,-3.0062044040946376,-2.9974386519300302,-2.9885106988654813,-2.9794564946169153,-2.970312497269217,-2.9611155264723887,-2.9519026151818153,-2.942710860539624,-2.9335772744975874,-2.9245386347830538,-2.915631336808022,-2.9068912471176627,-2.898353558968398,-2.8900526506170814,-2.88202194689189,-2.8742937846023384,-2.86689928233036,-2.8598682151267596,-2.853228894617596,-2.847008055003252,-2.8412307454092485,-2.8359202290222543,-2.831097889417447,-2.8267831444544007,-2.822993368088218,-2.8197438204107486,-2.8170475862035813,-2.8149155222502498,-2.813356213619796,-2.8123759390977248,-2.8119786459035567,-2.8121659337967615,-2.8129370486350953,-2.8142888854112647,-2.816216000755694,-2.818710634855055,-2.8217627426982945,-2.8253600345243512,-2.8294880253086823,-2.8341300930893483,-2.839267545897785,-2.844879697024766,-2.8509439483184758,-2.857435881179294,-2.864329354884878,-2.871596611849624,-2.879208389394667,-2.887134037578364,-2.895341642612787,-2.9037981553692847,-2.912469524455661],"y":[-3.3847653427634077,-3.385039737438937,-3.38738417435294,-3.391789213285418,-3.3982371166993204,-3.406701921163348,-3.4171495418975235,-3.4295379100205725,-3.443817141946462,-3.4599297402479907,-3.4778108251786404,-3.4973883959204137,-3.518583620505714,-3.541311153245859,-3.565479478388045,-3.590991278616985,-3.617743826917387,-3.645629400219391,-3.674535713161349,-3.7043463702233472,-3.734941334410882,-3.7661974106014724,-3.7979887416079365,-3.8301873149608623,-3.862663478369645,-3.8952864617864966,-3.927924903971275,-3.960447381436838,-3.992722937645037,-4.024621610322479,-4.056014954772728,-4.086776561077769,-4.1167825631061294,-4.145912137278072,-4.174047989079507,-4.201076825365607,-4.2268898105523025,-4.251383004858782,-4.2744577828362935,-4.296021230498019,-4.315986519450911,-4.334273256522981,-4.350807807478226,-4.365523593515721,-4.378361359358934,-4.3892694118558255,-4.39820382812892,-4.405128632437232,-4.410015941037877,-4.412846074464068,-4.413607636767373,-4.412297561405187,-4.40892112358861,-4.403491919041037,-4.396 ...

# %%
plot3D(pca_with_blank_df, colors, pca_with_blank, "blank");
# Out:
# <div>                            <div id="571200f5-9c14-460c-aa49-9b3392400efb" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("571200f5-9c14-460c-aa49-9b3392400efb")) {                    Plotly.newPlot(                        "571200f5-9c14-460c-aa49-9b3392400efb",                        [{"marker":{"color":"black","size":8},"mode":"markers+text","name":"Blank","text":["BCO_HEPT","BCO_EtOAc","BCO_EtOH","BCO_MEOH","BCO_HEX"],"textposition":"top center","x":[-2.9311360349885973,-2.9311360349885973,-2.9311360349885973,-2.9818865453148153,-3.0104892262314142],"y":[-3.8978801095991757,-3.8978801095991757,-3.8978801095991757,-3.7153938387658503,-4.086593724830583],"z":[0.25900470916830987,0.25900470916830987,0.25900470916830987,0.22248144862099717,0.28228859436040143],"type":"scatter3d"},{"marker":{"color":"blue","size":8},"mode":"markers+text","name":"TRADITIONAL METHOD","text":["FM_HEX","FM_HEX","FM_HEX","E_MeOH","E_MeOH","E_MeOH","FMAcOEt","FMAcOEt","FMAcOEt"],"textposition":"top center","x":[-2.6942349195182547,-2.6968382284794674,-2.6944715839692743,-10.035692180151338,-9.881092540988545,-9.958392360569938,-3.8486653381225446,-3.8483900793316037,-3.8503811179194054],"y":[-3.857250622181641,-3.85769710006535,-3.85729121108016,25.019764438707448,24.390498187408983,24.70513131305823,-9.25706125345761,-9.255453499114456,-9.267082922196632],"z":[0.2745784751712923,0.27440733488554536,0.2745629169634973,-7.895894530157719,-7.718438760360313,-7.807166645259018,-9.701833017592513,-9.698844766274485,-9.720459784141557],"type":"scatter3d"},{"marker":{"color":"green","size":8},"mode":"markers+text","name":"ALTERNATIVE METHOD","text":["E_EtOH","E_EtOH","E_EtOH","FEAcOEt","FEAcOEt","FEAcOEt","FE_HEP","FE_HEP","FE_HEP"],"textposition":"top center","x":[-6.56073267975014,-6.564402646023913,-6.601102308761643,-1.9184418593755954,-1.917226383269639,-1.9182392800246033,36.32364876004027,36.2010515804847,36.31880139276794],"y":[5.353997317565241,5.363352097572482,5.456899897644929,-5.504846038924803,-5.506774783788965,-5.505167496402162,4.8171471058467255,4.78992907976551,4.816070932892994],"z":[18.069877310161306,18.087886281446433,18.26797599429773,-0.9482002928526663,-0.949649228642249,-0.9484417821509297,0.07911482829055394,0.07967664494912197,0.07913704194745785],"type":"scatter3d"},{"marker":{"color":"cyan","size":8},"mode":"markers+text","name":"TRADITIONAL MODIFIED","text":["EMACOEt","EMACOEt","EMACOEt"],"textposition":"top center","x":[-3.0248257037765303,-3.025951105203412,-3.02491948722877],"y":[-4.395438888382474,-4.401415570409902,-4.395936945218093],"z":[-0.1589116729694371,-0.16393168957169235,-0.15933000768629146],"type":"scatter3d"},{"marker":{"color":"pink","size":8},"mode":"markers+text","name":"ALTERNATIVE MODIFIED","text":["EEACOEt","EEACOEt","EEACOEt"],"textposition":"top center","x":[-3.3337095213012384,-3.334192609484814,-3.3258159235304023],"y":[-5.394431476552146,-5.396227338192491,-5.365087332102088],"z":[-0.3027464829221146,-0.3034205843526233,-0.2917317536654397],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e ...

# %%
plot3D(pca_no_blank_df, colors, pca_no_blank, "noblank");
# Out:
# <div>                            <div id="03c48e93-ab62-481c-af4c-b62725e52449" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03c48e93-ab62-481c-af4c-b62725e52449")) {                    Plotly.newPlot(                        "03c48e93-ab62-481c-af4c-b62725e52449",                        [{"marker":{"color":"black","size":8},"mode":"markers+text","name":"Blank","text":[],"textposition":"top center","x":[],"y":[],"z":[],"type":"scatter3d"},{"marker":{"color":"blue","size":8},"mode":"markers+text","name":"TRADITIONAL METHOD","text":["FM_HEX","FM_HEX","FM_HEX","E_MeOH","E_MeOH","E_MeOH","FMAcOEt","FMAcOEt","FMAcOEt"],"textposition":"top center","x":[-2.716515391323981,-2.719291507103697,-2.7167677654857734,-10.660640830235486,-10.493268945106832,-10.576954887671162,-3.990056088858251,-3.989749814609779,-3.9919651983404076],"y":[-4.03590365479025,-4.036076673084413,-4.035919383726083,21.965940864169635,21.399781653445554,21.682861258807616,-10.172867518102425,-10.171031152342865,-10.184314198003701],"z":[0.30556982929135534,0.30525719290365094,0.3055414078015639,-7.474611465369345,-7.305928883337333,-7.39027017435334,-8.669359980191809,-8.666676036222352,-8.686089897601448],"type":"scatter3d"},{"marker":{"color":"green","size":8},"mode":"markers+text","name":"ALTERNATIVE METHOD","text":["E_EtOH","E_EtOH","E_EtOH","FEAcOEt","FEAcOEt","FEAcOEt","FE_HEP","FE_HEP","FE_HEP"],"textposition":"top center","x":[-6.898591330539492,-6.902564484637836,-6.942296025621266,-2.069683842376047,-2.068604276761041,-2.0695039147735454,32.764954681419354,32.65335301346809,32.76054206544622],"y":[3.9316120770938476,3.9396841300732715,4.020404659867544,-5.929849956736015,-5.932104249559192,-5.930225672206544,4.876282175186835,4.848399227830491,4.875179711924937],"z":[16.742687466519033,16.759336169803685,16.92582320265007,-0.7863988936538748,-0.7876753715234457,-0.7866116399654693,0.04917871068526081,0.04989059712837629,0.04920685794818458],"type":"scatter3d"},{"marker":{"color":"cyan","size":8},"mode":"markers+text","name":"TRADITIONAL MODIFIED","text":["EMACOEt","EMACOEt","EMACOEt"],"textposition":"top center","x":[-3.074367304974155,-3.0756312734750075,-3.074472635682559],"y":[-4.650380690011489,-4.657572670437344,-4.650980021713644],"z":[-0.09911900941934915,-0.10363839593502011,-0.0994956249623219],"type":"scatter3d"},{"marker":{"color":"pink","size":8},"mode":"markers+text","name":"ALTERNATIVE MODIFIED","text":["EEACOEt","EEACOEt","EEACOEt"],"textposition":"top center","x":[-3.3851942897945073,-3.385693552629526,-3.377036400333402],"y":[-5.727925521826489,-5.729937054469209,-5.695057341389872],"z":[-0.2152263651150521,-0.2158171806548025,-0.20557251642632057],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[ ...
